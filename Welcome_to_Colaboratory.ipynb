# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicky714/SimpleLinearRegression/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SIMPLEREGRESSION:
  def __init__(self):

    self.m=None
    self.b=None

  def fit(self,x_train,y_train):

    num =0
    den =0

    for i in range(x_train.shape[0]):

      num = num + ((x_train.iloc[i]-x_train.mean())*(y_train.iloc[i]-y_train.mean()))
      den = den + ((x_train.iloc[i]-x_train.mean())*(x_train.iloc[i]-x_train.mean()))

    self.m = num/den
    self.b = y_train.mean() - (self.m * x_train.mean())

    print(self.m)
    print(self.b)

  def predict(self,x_test):

    print(x_test)

    return self.m * x_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/placement.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
df.shape[0]
# Out:
# 200

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
X_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.2)

# %%
lr = SIMPLEREGRESSION()

# %%
X_train.sample(5)
# Out:
#      cgpa
# 120  5.23
# 195  6.93
# 171  8.01
# 41   6.89
# 170  6.22

# %%
y_train.sample(5)
# Out:
# 109    4.06
# 179    3.03
# 167    3.60
# 98     3.83
# 55     3.39
# Name: package, dtype: float64

# %%
x.sample(5)
# Out:
#      cgpa
# 70   5.79
# 160  7.13
# 107  6.33
# 52   8.37
# 174  7.32

# %%
y.sample(5)
# Out:
# 137    3.13
# 109    4.06
# 119    2.65
# 110    3.76
# 197    3.24
# Name: package, dtype: float64

# %%
X_train.iloc[:,-1].sample(5)
# Out:
# 98     7.69
# 5      7.89
# 177    7.09
# 188    7.35
# 151    6.12
# Name: cgpa, dtype: float64

# %%
X_train.index
# Out:
# Index([137, 163, 111, 123, 109, 141,  41, 130, 140,   5,
#        ...
#        177, 162,   7, 104,  75,  43,  22,  72,  15, 168],
#       dtype='int64', length=160)

# %%
y_train.index
# Out:
# Index([137, 163, 111, 123, 109, 141,  41, 130, 140,   5,
#        ...
#        177, 162,   7, 104,  75,  43,  22,  72,  15, 168],
#       dtype='int64', length=160)

# %%
X_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)

# %%
X_train
# Out:
#      cgpa
# 0    7.14
# 1    8.93
# 2    5.42
# 3    5.10
# 4    7.77
# ..    ...
# 155  7.66
# 156  6.14
# 157  7.78
# 158  7.25
# 159  8.65
#
# [160 rows x 1 columns]

# %%
y_train
# Out:
# 0      3.13
# 1      3.91
# 2      2.25
# 3      2.30
# 4      4.06
#        ...
# 155    2.76
# 156    2.30
# 157    3.62
# 158    3.23
# 159    3.52
# Name: package, Length: 160, dtype: float64

# %%
lr.fit(X_train,y_train)
# Out:
# cgpa    0.557952
# dtype: float64
# cgpa   -0.896112
# dtype: float64

# %%
type(df)
type(X_train)
type(y_train)
# Out:
# pandas.core.series.Series

# %%
lr.predict(x_test)
# Out:
#          cgpa
# 112  3.891116
# 29   3.093245
# 182  2.384646
# 199  2.574349
# 193  1.653729
# 85   1.776478
# 10   2.072193
# 54   2.931439
# 115  3.762787
# 35   2.937018
# 12   4.091979
# 92   3.511709
# 13   2.970495
# 126  2.401384
# 174  3.188097
# 2    3.467073
# 44   1.943864
# 3    3.243892
# 113  2.976075
# 14   3.416857
# 23   2.557611
# 25   3.165778
# 6    2.858905
# 134  3.121142
# 165  3.684674
# 173  2.870064
# 45   3.494970
# 65   3.344323
# 48   3.919014
# 122  1.960602
# 178  3.651197
# 64   3.210415
# 9    3.740469
# 57   2.786371
# 78   2.780792
# 71   3.271789
# 128  3.528447
# 176  2.613406
# 131  2.658042
# 53   2.713837
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='line', figsize=(8, 4), title='cgpa')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.iloc[112]
# Out:
# cgpa       8.58
# package    4.10
# Name: 112, dtype: float64

# %%
x_test.iloc[0]
# Out:
# cgpa    8.58
# Name: 112, dtype: float64

# %%
print(lr.predict(x_test.iloc[0]))
# Out:
# cgpa    8.58
# Name: 112, dtype: float64
# cgpa    3.891116
# dtype: float64
